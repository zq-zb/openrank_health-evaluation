# %%
import os
import pandas as pd 

def load_reference_columns(reference_file_path,column_name='指标名称'):
    df_ref=pd.read_csv(reference_file_path)
    if column_name in df_ref.columns:
        return df_ref[column_name]

def process_single_file(input_file_path, reference_series, output_dir):
    try:
        # 加载CSV文件
        df = pd.read_csv(input_file_path)
        # 获取当前文件的列名
        column_name='指标名称'
        # 对比并补全缺失的列
        if column_name not in df.columns:
            # 如果当前文件不存在该列，则该列填充为NaN
            df[column_name]=float('nan')
            
        # 确保日期格式一致
        reference_series = pd.to_datetime(reference_series, format='%Y-%m').dt.strftime('%Y-%m')
        df[column_name] = pd.to_datetime(df[column_name], format='%Y-%m', errors='coerce').dt.strftime('%Y-%m')

        # 创建一个完整的日期索引以检查缺失的日期
        complete_dates =pd.DataFrame({'指标名称': reference_series.unique()})
        df_complete=pd.merge(complete_dates,df,on='指标名称',how='left')
        # 构建输出文件路径
        base_name=os.path.basename(input_file_path)
        output_file_path=os.path.join(output_dir, base_name)

        # 保存更新后的数据到新的CSV文件
        df_complete.to_csv(output_file_path, index=False)

        print(f"已处理并保存到 {output_file_path}")

    except Exception as e:
        print(f"处理文件 {input_file_path} 时出错: {e}")

def find_matching_active_file(base_dir, input_file_path):
    dir_path = os.path.dirname(input_file_path)
    file_name=os.path.basename(input_file_path)
    parts=file_name.split('_',2)
    file_prefix=parts[0]+'_'+parts[1]
    for root, dirs, files in os.walk(dir_path):
        for file in files: 
            if file.endswith('active_dates_and_times.csv') and file.startswith(file_prefix): # 匹配寻找对应的时间基准
                return os.path.join(root, file)
    return None

def process_all_files(base_dir,output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, dirs, files in os.walk(base_dir):
        for file in files:
             if file.endswith('.csv') and not file.endswith('active_dates_and_times.csv'):
                input_file_path=os.path.join(root, file)
                # 查找对应的 active_dates_and_times.csv 文件
                matching_active_file=find_matching_active_file(base_dir, input_file_path)
                if matching_active_file:
                    # 加载参考文件的列名
                    reference_series=load_reference_columns(matching_active_file)
                    # 处理单个文件
                    process_single_file(input_file_path, reference_series, output_dir)
                else:
                    print(f"警告: 没有找到与 {input_file_path} 对应的 active_dates_and_times.csv 文件")


base_dir='./outputdata 原数据'
output_dir='./add 仅填补日期 无补0'
process_all_files(base_dir,output_dir)
# Out:
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\AdguardTeam_AdguardFilters_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\airbytehq_airbyte_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\alibaba_nacos_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_angular_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\angular_components_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ankidroid_Anki-Android_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ansible_ansible_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ant-design_ant-design_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_airflow_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_apisix_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_arrow_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_beam_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_dolphinscheduler_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_doris_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_flink_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_hudi_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_iceberg_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_pulsar_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_shardingsphere_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_spark_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_superset_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apache_tvm_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\apple_swift_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\appsmithorg_appsmith_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\archway-network_testnets_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ArduPilot_ardupilot_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ArduPilot_ardupilot_activity_details.csv
# ...
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xamarin_xamarin-macios_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\xbmc_xbmc_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yt-dlp_yt-dlp_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\yuzu-emu_yuzu_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zephyrproject-rtos_zephyr_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zero-to-mastery_start-here-guidelines_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\ziglang_zig_technical_fork.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_activity.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_activity_details.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_attention.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_bus_factor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_bus_factor_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_change_requests.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_change_requests_accepted.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_change_requests_reviews.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_change_request_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_change_request_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_change_request_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_code_change_lines_add.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_code_change_lines_remove.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_code_change_lines_sum.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_contributor.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_contributor_email_suffixes.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_inactive_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_issues_and_change_request_active.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_issues_closed.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_issues_new.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_issue_age.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_issue_comments.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_issue_resolution_duration.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_issue_response_time.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_meta.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_new_contributors.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_new_contributors_detail.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_openrank.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_participants.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_stars.csv
# 已处理并保存到 ./add 仅填补日期 无补0\zulip_zulip_technical_fork.csv
