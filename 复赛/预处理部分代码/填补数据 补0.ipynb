# %%
import os
import pandas as pd

def process_all_files(base_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if  file.endswith('contributor.csv') or file.endswith('new_contributors.csv') or file.endswith('inactive_contributors.csv') or file.endswith('change_requests.csv') or file.endswith('change_requests_accepted.csv') or file.endswith('change_requests_reviews.csv') or file.endswith('issues_new.csv') or file.endswith('issues_closed.csv') or file.endswith('code_change_lines_add.csv') or file.endswith('code_change_lines_remove.csv') or file.endswith('code_change_lines_sum.csv') or file.endswith('issue_comments.csv') or file.endswith('bus_factor.csv'):
                input_file_path = os.path.join(root, file)
                # 处理单个文件
                df=pd.read_csv(input_file_path)
                df['指标值']=df['指标值'].fillna(0)

                base_name = os.path.basename(input_file_path)
                output_file_path = os.path.join(output_dir, base_name)

                df.to_csv(output_file_path, index=False)

                print(f"已处理并保存到 {output_file_path}")

# 指定基础目录和输出目录
base_dir = './add 仅填补日期 无补0'
output_dir = './填补数据 补0+KNN近邻+问题变更等'
process_all_files(base_dir, output_dir)
# Out:
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_code_change_lines_sum.csv
# ...
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Dota2-Gameplay_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Dota2-Gameplay_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Dota2-Gameplay_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill-CustomBuild_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_new_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_bus_factor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_change_requests.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_change_requests_accepted.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_change_requests_reviews.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_code_change_lines_add.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_code_change_lines_remove.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_code_change_lines_sum.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_inactive_contributors.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_issues_closed.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_issues_new.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_issue_comments.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_new_contributors.csv
