# %%
import os
import json
import csv

def parse_opendigger_json(file_path):
    with open(file_path,'r',encoding='utf-8') as file:
        data=json.load(file)
    return data

def write_to_csv(data,csv_file_path):

    fieldnames=["指标名称","指标值"]
    try:
        with open(csv_file_path,'w',newline='',encoding='utf-8') as csv_file:
            writer=csv.DictWriter(csv_file,fieldnames=fieldnames)
            writer.writeheader()

            for key, value in data.items():
                writer.writerow({"指标名称": key,"指标值": value})
        print(f"已保存成功:{csv_file_path}")
    except Exception as e:
        print(f"写入CSV失败: {e}")

def batch_process_json_files(root_dir, output_dir):
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for subdir, _, files in os.walk(root_dir):
        # 获取子文件夹名称和父文件夹名称，用于CSV文件命名
        folder_name=os.path.basename(subdir)
        parent_folder_name=os.path.basename(os.path.dirname(subdir)) # 获取子文件夹名的父文件名（仓库名）
        
        if not folder_name:  # 如果是根目录则跳过
            continue
        
        json_files=[f for f in files if f.endswith('.json')]
        for json_file in json_files:
            json_file_path=os.path.join(subdir,json_file)
            
            base_name, _=os.path.splitext(json_file)  # 分离文件名和扩展名
            
            # 构建输出CSV文件名，使用父文件夹和当前文件夹名称
            csv_file_name=f"{parent_folder_name}_{folder_name}_{base_name}.csv"
            csv_file_path=os.path.join(output_dir, csv_file_name)
            
            data=parse_opendigger_json(json_file_path)
            write_to_csv(data,csv_file_path)
            print(f"Processed JSON file: {json_file_path}")

root_directory = './top_300_metrics'
output_directory = './outputdata 原数据'  # 输出CSV文件的目标文件夹路径
batch_process_json_files(root_directory, output_directory)
# Out:
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\active_dates_and_times.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_activity.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\activity.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_activity_details.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\activity_details.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_attention.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\attention.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_bus_factor.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\bus_factor.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\bus_factor_detail.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_change_requests.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\change_requests.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\change_requests_accepted.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\change_requests_reviews.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_change_request_age.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\change_request_age.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\change_request_resolution_duration.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\change_request_response_time.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\code_change_lines_add.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\code_change_lines_remove.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\code_change_lines_sum.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\contributor_email_suffixes.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\inactive_contributors.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\issues_and_change_request_active.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_issues_closed.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\issues_closed.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_issues_new.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\issues_new.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_issue_age.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\issue_age.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_issue_comments.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\issue_comments.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\issue_resolution_duration.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\issue_response_time.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_meta.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\meta.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_new_contributors.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\new_contributors.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\new_contributors_detail.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_openrank.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\openrank.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_participants.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\participants.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_stars.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\stars.json
# 已保存成功:./outdata\AdguardTeam_AdguardFilters_technical_fork.csv
# Processed JSON file: ./top_300_metrics\AdguardTeam\AdguardFilters\technical_fork.json
# 已保存成功:./outdata\airbytehq_airbyte_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\active_dates_and_times.json
# 已保存成功:./outdata\airbytehq_airbyte_activity.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\activity.json
# 已保存成功:./outdata\airbytehq_airbyte_activity_details.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\activity_details.json
# 已保存成功:./outdata\airbytehq_airbyte_attention.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\attention.json
# 已保存成功:./outdata\airbytehq_airbyte_bus_factor.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\bus_factor.json
# 已保存成功:./outdata\airbytehq_airbyte_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\bus_factor_detail.json
# 已保存成功:./outdata\airbytehq_airbyte_change_requests.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\change_requests.json
# 已保存成功:./outdata\airbytehq_airbyte_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\change_requests_accepted.json
# 已保存成功:./outdata\airbytehq_airbyte_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\change_requests_reviews.json
# 已保存成功:./outdata\airbytehq_airbyte_change_request_age.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\change_request_age.json
# 已保存成功:./outdata\airbytehq_airbyte_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\change_request_resolution_duration.json
# 已保存成功:./outdata\airbytehq_airbyte_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\change_request_response_time.json
# 已保存成功:./outdata\airbytehq_airbyte_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\code_change_lines_add.json
# 已保存成功:./outdata\airbytehq_airbyte_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\code_change_lines_remove.json
# 已保存成功:./outdata\airbytehq_airbyte_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\code_change_lines_sum.json
# 已保存成功:./outdata\airbytehq_airbyte_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\contributor_email_suffixes.json
# 已保存成功:./outdata\airbytehq_airbyte_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\inactive_contributors.json
# 已保存成功:./outdata\airbytehq_airbyte_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\issues_and_change_request_active.json
# 已保存成功:./outdata\airbytehq_airbyte_issues_closed.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\issues_closed.json
# 已保存成功:./outdata\airbytehq_airbyte_issues_new.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\issues_new.json
# 已保存成功:./outdata\airbytehq_airbyte_issue_age.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\issue_age.json
# 已保存成功:./outdata\airbytehq_airbyte_issue_comments.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\issue_comments.json
# 已保存成功:./outdata\airbytehq_airbyte_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\issue_resolution_duration.json
# 已保存成功:./outdata\airbytehq_airbyte_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\issue_response_time.json
# 已保存成功:./outdata\airbytehq_airbyte_meta.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\meta.json
# 已保存成功:./outdata\airbytehq_airbyte_new_contributors.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\new_contributors.json
# 已保存成功:./outdata\airbytehq_airbyte_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\new_contributors_detail.json
# 已保存成功:./outdata\airbytehq_airbyte_openrank.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\openrank.json
# 已保存成功:./outdata\airbytehq_airbyte_participants.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\participants.json
# 已保存成功:./outdata\airbytehq_airbyte_stars.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\stars.json
# 已保存成功:./outdata\airbytehq_airbyte_technical_fork.csv
# Processed JSON file: ./top_300_metrics\airbytehq\airbyte\technical_fork.json
# 已保存成功:./outdata\alibaba_nacos_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\active_dates_and_times.json
# 已保存成功:./outdata\alibaba_nacos_activity.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\activity.json
# 已保存成功:./outdata\alibaba_nacos_activity_details.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\activity_details.json
# 已保存成功:./outdata\alibaba_nacos_attention.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\attention.json
# 已保存成功:./outdata\alibaba_nacos_bus_factor.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\bus_factor.json
# 已保存成功:./outdata\alibaba_nacos_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\bus_factor_detail.json
# 已保存成功:./outdata\alibaba_nacos_change_requests.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\change_requests.json
# 已保存成功:./outdata\alibaba_nacos_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\change_requests_accepted.json
# 已保存成功:./outdata\alibaba_nacos_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\change_requests_reviews.json
# 已保存成功:./outdata\alibaba_nacos_change_request_age.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\change_request_age.json
# 已保存成功:./outdata\alibaba_nacos_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\change_request_resolution_duration.json
# 已保存成功:./outdata\alibaba_nacos_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\change_request_response_time.json
# 已保存成功:./outdata\alibaba_nacos_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\code_change_lines_add.json
# 已保存成功:./outdata\alibaba_nacos_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\code_change_lines_remove.json
# 已保存成功:./outdata\alibaba_nacos_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\code_change_lines_sum.json
# 已保存成功:./outdata\alibaba_nacos_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\contributor_email_suffixes.json
# 已保存成功:./outdata\alibaba_nacos_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\inactive_contributors.json
# 已保存成功:./outdata\alibaba_nacos_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\issues_and_change_request_active.json
# 已保存成功:./outdata\alibaba_nacos_issues_closed.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\issues_closed.json
# 已保存成功:./outdata\alibaba_nacos_issues_new.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\issues_new.json
# 已保存成功:./outdata\alibaba_nacos_issue_age.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\issue_age.json
# 已保存成功:./outdata\alibaba_nacos_issue_comments.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\issue_comments.json
# 已保存成功:./outdata\alibaba_nacos_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\issue_resolution_duration.json
# 已保存成功:./outdata\alibaba_nacos_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\issue_response_time.json
# 已保存成功:./outdata\alibaba_nacos_meta.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\meta.json
# 已保存成功:./outdata\alibaba_nacos_new_contributors.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\new_contributors.json
# 已保存成功:./outdata\alibaba_nacos_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\new_contributors_detail.json
# 已保存成功:./outdata\alibaba_nacos_openrank.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\openrank.json
# 已保存成功:./outdata\alibaba_nacos_participants.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\participants.json
# 已保存成功:./outdata\alibaba_nacos_stars.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\stars.json
# 已保存成功:./outdata\alibaba_nacos_technical_fork.csv
# Processed JSON file: ./top_300_metrics\alibaba\nacos\technical_fork.json
# 已保存成功:./outdata\angular_angular_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\angular\angular\active_dates_and_times.json
# 已保存成功:./outdata\angular_angular_activity.csv
# Processed JSON file: ./top_300_metrics\angular\angular\activity.json
# 已保存成功:./outdata\angular_angular_activity_details.csv
# Processed JSON file: ./top_300_metrics\angular\angular\activity_details.json
# 已保存成功:./outdata\angular_angular_attention.csv
# Processed JSON file: ./top_300_metrics\angular\angular\attention.json
# 已保存成功:./outdata\angular_angular_bus_factor.csv
# Processed JSON file: ./top_300_metrics\angular\angular\bus_factor.json
# 已保存成功:./outdata\angular_angular_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\angular\angular\bus_factor_detail.json
# 已保存成功:./outdata\angular_angular_change_requests.csv
# Processed JSON file: ./top_300_metrics\angular\angular\change_requests.json
# 已保存成功:./outdata\angular_angular_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\angular\angular\change_requests_accepted.json
# 已保存成功:./outdata\angular_angular_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\angular\angular\change_requests_reviews.json
# 已保存成功:./outdata\angular_angular_change_request_age.csv
# Processed JSON file: ./top_300_metrics\angular\angular\change_request_age.json
# 已保存成功:./outdata\angular_angular_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\angular\angular\change_request_resolution_duration.json
# 已保存成功:./outdata\angular_angular_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\angular\angular\change_request_response_time.json
# 已保存成功:./outdata\angular_angular_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\angular\angular\code_change_lines_add.json
# 已保存成功:./outdata\angular_angular_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\angular\angular\code_change_lines_remove.json
# 已保存成功:./outdata\angular_angular_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\angular\angular\code_change_lines_sum.json
# 已保存成功:./outdata\angular_angular_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\angular\angular\contributor_email_suffixes.json
# 已保存成功:./outdata\angular_angular_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\angular\angular\inactive_contributors.json
# 已保存成功:./outdata\angular_angular_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\angular\angular\issues_and_change_request_active.json
# 已保存成功:./outdata\angular_angular_issues_closed.csv
# Processed JSON file: ./top_300_metrics\angular\angular\issues_closed.json
# 已保存成功:./outdata\angular_angular_issues_new.csv
# Processed JSON file: ./top_300_metrics\angular\angular\issues_new.json
# 已保存成功:./outdata\angular_angular_issue_age.csv
# Processed JSON file: ./top_300_metrics\angular\angular\issue_age.json
# 已保存成功:./outdata\angular_angular_issue_comments.csv
# Processed JSON file: ./top_300_metrics\angular\angular\issue_comments.json
# 已保存成功:./outdata\angular_angular_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\angular\angular\issue_resolution_duration.json
# 已保存成功:./outdata\angular_angular_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\angular\angular\issue_response_time.json
# 已保存成功:./outdata\angular_angular_meta.csv
# Processed JSON file: ./top_300_metrics\angular\angular\meta.json
# 已保存成功:./outdata\angular_angular_new_contributors.csv
# Processed JSON file: ./top_300_metrics\angular\angular\new_contributors.json
# 已保存成功:./outdata\angular_angular_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\angular\angular\new_contributors_detail.json
# 已保存成功:./outdata\angular_angular_openrank.csv
# Processed JSON file: ./top_300_metrics\angular\angular\openrank.json
# 已保存成功:./outdata\angular_angular_participants.csv
# Processed JSON file: ./top_300_metrics\angular\angular\participants.json
# 已保存成功:./outdata\angular_angular_stars.csv
# Processed JSON file: ./top_300_metrics\angular\angular\stars.json
# 已保存成功:./outdata\angular_angular_technical_fork.csv
# Processed JSON file: ./top_300_metrics\angular\angular\technical_fork.json
# 已保存成功:./outdata\angular_components_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\angular\components\active_dates_and_times.json
# 已保存成功:./outdata\angular_components_activity.csv
# Processed JSON file: ./top_300_metrics\angular\components\activity.json
# 已保存成功:./outdata\angular_components_activity_details.csv
# Processed JSON file: ./top_300_metrics\angular\components\activity_details.json
# 已保存成功:./outdata\angular_components_attention.csv
# Processed JSON file: ./top_300_metrics\angular\components\attention.json
# 已保存成功:./outdata\angular_components_bus_factor.csv
# Processed JSON file: ./top_300_metrics\angular\components\bus_factor.json
# 已保存成功:./outdata\angular_components_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\angular\components\bus_factor_detail.json
# 已保存成功:./outdata\angular_components_change_requests.csv
# Processed JSON file: ./top_300_metrics\angular\components\change_requests.json
# 已保存成功:./outdata\angular_components_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\angular\components\change_requests_accepted.json
# 已保存成功:./outdata\angular_components_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\angular\components\change_requests_reviews.json
# 已保存成功:./outdata\angular_components_change_request_age.csv
# Processed JSON file: ./top_300_metrics\angular\components\change_request_age.json
# 已保存成功:./outdata\angular_components_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\angular\components\change_request_resolution_duration.json
# 已保存成功:./outdata\angular_components_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\angular\components\change_request_response_time.json
# 已保存成功:./outdata\angular_components_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\angular\components\code_change_lines_add.json
# 已保存成功:./outdata\angular_components_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\angular\components\code_change_lines_remove.json
# 已保存成功:./outdata\angular_components_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\angular\components\code_change_lines_sum.json
# 已保存成功:./outdata\angular_components_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\angular\components\contributor_email_suffixes.json
# 已保存成功:./outdata\angular_components_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\angular\components\inactive_contributors.json
# 已保存成功:./outdata\angular_components_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\angular\components\issues_and_change_request_active.json
# 已保存成功:./outdata\angular_components_issues_closed.csv
# Processed JSON file: ./top_300_metrics\angular\components\issues_closed.json
# 已保存成功:./outdata\angular_components_issues_new.csv
# Processed JSON file: ./top_300_metrics\angular\components\issues_new.json
# 已保存成功:./outdata\angular_components_issue_age.csv
# Processed JSON file: ./top_300_metrics\angular\components\issue_age.json
# 已保存成功:./outdata\angular_components_issue_comments.csv
# Processed JSON file: ./top_300_metrics\angular\components\issue_comments.json
# 已保存成功:./outdata\angular_components_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\angular\components\issue_resolution_duration.json
# 已保存成功:./outdata\angular_components_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\angular\components\issue_response_time.json
# 已保存成功:./outdata\angular_components_meta.csv
# Processed JSON file: ./top_300_metrics\angular\components\meta.json
# 已保存成功:./outdata\angular_components_new_contributors.csv
# Processed JSON file: ./top_300_metrics\angular\components\new_contributors.json
# 已保存成功:./outdata\angular_components_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\angular\components\new_contributors_detail.json
# 已保存成功:./outdata\angular_components_openrank.csv
# Processed JSON file: ./top_300_metrics\angular\components\openrank.json
# 已保存成功:./outdata\angular_components_participants.csv
# Processed JSON file: ./top_300_metrics\angular\components\participants.json
# 已保存成功:./outdata\angular_components_stars.csv
# Processed JSON file: ./top_300_metrics\angular\components\stars.json
# 已保存成功:./outdata\angular_components_technical_fork.csv
# Processed JSON file: ./top_300_metrics\angular\components\technical_fork.json
# 已保存成功:./outdata\ankidroid_Anki-Android_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\active_dates_and_times.json
# 已保存成功:./outdata\ankidroid_Anki-Android_activity.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\activity.json
# 已保存成功:./outdata\ankidroid_Anki-Android_activity_details.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\activity_details.json
# 已保存成功:./outdata\ankidroid_Anki-Android_attention.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\attention.json
# 已保存成功:./outdata\ankidroid_Anki-Android_bus_factor.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\bus_factor.json
# 已保存成功:./outdata\ankidroid_Anki-Android_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\bus_factor_detail.json
# 已保存成功:./outdata\ankidroid_Anki-Android_change_requests.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\change_requests.json
# 已保存成功:./outdata\ankidroid_Anki-Android_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\change_requests_accepted.json
# 已保存成功:./outdata\ankidroid_Anki-Android_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\change_requests_reviews.json
# 已保存成功:./outdata\ankidroid_Anki-Android_change_request_age.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\change_request_age.json
# 已保存成功:./outdata\ankidroid_Anki-Android_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\change_request_resolution_duration.json
# 已保存成功:./outdata\ankidroid_Anki-Android_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\change_request_response_time.json
# 已保存成功:./outdata\ankidroid_Anki-Android_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\code_change_lines_add.json
# 已保存成功:./outdata\ankidroid_Anki-Android_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\code_change_lines_remove.json
# 已保存成功:./outdata\ankidroid_Anki-Android_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\code_change_lines_sum.json
# 已保存成功:./outdata\ankidroid_Anki-Android_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\contributor_email_suffixes.json
# 已保存成功:./outdata\ankidroid_Anki-Android_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\inactive_contributors.json
# 已保存成功:./outdata\ankidroid_Anki-Android_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\issues_and_change_request_active.json
# 已保存成功:./outdata\ankidroid_Anki-Android_issues_closed.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\issues_closed.json
# 已保存成功:./outdata\ankidroid_Anki-Android_issues_new.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\issues_new.json
# 已保存成功:./outdata\ankidroid_Anki-Android_issue_age.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\issue_age.json
# 已保存成功:./outdata\ankidroid_Anki-Android_issue_comments.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\issue_comments.json
# 已保存成功:./outdata\ankidroid_Anki-Android_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\issue_resolution_duration.json
# 已保存成功:./outdata\ankidroid_Anki-Android_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\issue_response_time.json
# 已保存成功:./outdata\ankidroid_Anki-Android_meta.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\meta.json
# 已保存成功:./outdata\ankidroid_Anki-Android_new_contributors.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\new_contributors.json
# 已保存成功:./outdata\ankidroid_Anki-Android_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\new_contributors_detail.json
# 已保存成功:./outdata\ankidroid_Anki-Android_openrank.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\openrank.json
# 已保存成功:./outdata\ankidroid_Anki-Android_participants.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\participants.json
# 已保存成功:./outdata\ankidroid_Anki-Android_stars.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\stars.json
# 已保存成功:./outdata\ankidroid_Anki-Android_technical_fork.csv
# Processed JSON file: ./top_300_metrics\ankidroid\Anki-Android\technical_fork.json
# 已保存成功:./outdata\ansible_ansible_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\active_dates_and_times.json
# 已保存成功:./outdata\ansible_ansible_activity.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\activity.json
# 已保存成功:./outdata\ansible_ansible_activity_details.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\activity_details.json
# 已保存成功:./outdata\ansible_ansible_attention.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\attention.json
# 已保存成功:./outdata\ansible_ansible_bus_factor.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\bus_factor.json
# 已保存成功:./outdata\ansible_ansible_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\bus_factor_detail.json
# 已保存成功:./outdata\ansible_ansible_change_requests.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\change_requests.json
# 已保存成功:./outdata\ansible_ansible_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\change_requests_accepted.json
# 已保存成功:./outdata\ansible_ansible_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\change_requests_reviews.json
# 已保存成功:./outdata\ansible_ansible_change_request_age.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\change_request_age.json
# 已保存成功:./outdata\ansible_ansible_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\change_request_resolution_duration.json
# 已保存成功:./outdata\ansible_ansible_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\change_request_response_time.json
# 已保存成功:./outdata\ansible_ansible_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\code_change_lines_add.json
# 已保存成功:./outdata\ansible_ansible_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\code_change_lines_remove.json
# 已保存成功:./outdata\ansible_ansible_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\code_change_lines_sum.json
# 已保存成功:./outdata\ansible_ansible_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\contributor_email_suffixes.json
# 已保存成功:./outdata\ansible_ansible_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\inactive_contributors.json
# 已保存成功:./outdata\ansible_ansible_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\issues_and_change_request_active.json
# 已保存成功:./outdata\ansible_ansible_issues_closed.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\issues_closed.json
# 已保存成功:./outdata\ansible_ansible_issues_new.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\issues_new.json
# 已保存成功:./outdata\ansible_ansible_issue_age.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\issue_age.json
# 已保存成功:./outdata\ansible_ansible_issue_comments.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\issue_comments.json
# 已保存成功:./outdata\ansible_ansible_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\issue_resolution_duration.json
# 已保存成功:./outdata\ansible_ansible_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\issue_response_time.json
# 已保存成功:./outdata\ansible_ansible_meta.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\meta.json
# 已保存成功:./outdata\ansible_ansible_new_contributors.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\new_contributors.json
# 已保存成功:./outdata\ansible_ansible_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\new_contributors_detail.json
# 已保存成功:./outdata\ansible_ansible_openrank.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\openrank.json
# 已保存成功:./outdata\ansible_ansible_participants.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\participants.json
# 已保存成功:./outdata\ansible_ansible_stars.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\stars.json
# 已保存成功:./outdata\ansible_ansible_technical_fork.csv
# Processed JSON file: ./top_300_metrics\ansible\ansible\technical_fork.json
# 已保存成功:./outdata\ant-design_ant-design_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\active_dates_and_times.json
# 已保存成功:./outdata\ant-design_ant-design_activity.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\activity.json
# 已保存成功:./outdata\ant-design_ant-design_activity_details.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\activity_details.json
# 已保存成功:./outdata\ant-design_ant-design_attention.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\attention.json
# 已保存成功:./outdata\ant-design_ant-design_bus_factor.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\bus_factor.json
# 已保存成功:./outdata\ant-design_ant-design_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\bus_factor_detail.json
# 已保存成功:./outdata\ant-design_ant-design_change_requests.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\change_requests.json
# 已保存成功:./outdata\ant-design_ant-design_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\change_requests_accepted.json
# 已保存成功:./outdata\ant-design_ant-design_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\change_requests_reviews.json
# 已保存成功:./outdata\ant-design_ant-design_change_request_age.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\change_request_age.json
# 已保存成功:./outdata\ant-design_ant-design_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\change_request_resolution_duration.json
# 已保存成功:./outdata\ant-design_ant-design_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\change_request_response_time.json
# 已保存成功:./outdata\ant-design_ant-design_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\code_change_lines_add.json
# 已保存成功:./outdata\ant-design_ant-design_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\code_change_lines_remove.json
# 已保存成功:./outdata\ant-design_ant-design_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\code_change_lines_sum.json
# 已保存成功:./outdata\ant-design_ant-design_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\contributor_email_suffixes.json
# 已保存成功:./outdata\ant-design_ant-design_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\inactive_contributors.json
# 已保存成功:./outdata\ant-design_ant-design_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\issues_and_change_request_active.json
# 已保存成功:./outdata\ant-design_ant-design_issues_closed.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\issues_closed.json
# 已保存成功:./outdata\ant-design_ant-design_issues_new.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\issues_new.json
# 已保存成功:./outdata\ant-design_ant-design_issue_age.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\issue_age.json
# 已保存成功:./outdata\ant-design_ant-design_issue_comments.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\issue_comments.json
# 已保存成功:./outdata\ant-design_ant-design_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\issue_resolution_duration.json
# 已保存成功:./outdata\ant-design_ant-design_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\issue_response_time.json
# 已保存成功:./outdata\ant-design_ant-design_meta.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\meta.json
# 已保存成功:./outdata\ant-design_ant-design_new_contributors.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\new_contributors.json
# 已保存成功:./outdata\ant-design_ant-design_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\new_contributors_detail.json
# 已保存成功:./outdata\ant-design_ant-design_openrank.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\openrank.json
# 已保存成功:./outdata\ant-design_ant-design_participants.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\participants.json
# 已保存成功:./outdata\ant-design_ant-design_stars.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\stars.json
# 已保存成功:./outdata\ant-design_ant-design_technical_fork.csv
# Processed JSON file: ./top_300_metrics\ant-design\ant-design\technical_fork.json
# 已保存成功:./outdata\apache_airflow_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\active_dates_and_times.json
# 已保存成功:./outdata\apache_airflow_activity.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\activity.json
# 已保存成功:./outdata\apache_airflow_activity_details.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\activity_details.json
# 已保存成功:./outdata\apache_airflow_attention.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\attention.json
# 已保存成功:./outdata\apache_airflow_bus_factor.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\bus_factor.json
# 已保存成功:./outdata\apache_airflow_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\bus_factor_detail.json
# 已保存成功:./outdata\apache_airflow_change_requests.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\change_requests.json
# 已保存成功:./outdata\apache_airflow_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\change_requests_accepted.json
# 已保存成功:./outdata\apache_airflow_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\change_requests_reviews.json
# 已保存成功:./outdata\apache_airflow_change_request_age.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\change_request_age.json
# 已保存成功:./outdata\apache_airflow_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\change_request_resolution_duration.json
# 已保存成功:./outdata\apache_airflow_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\change_request_response_time.json
# 已保存成功:./outdata\apache_airflow_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\code_change_lines_add.json
# 已保存成功:./outdata\apache_airflow_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\code_change_lines_remove.json
# 已保存成功:./outdata\apache_airflow_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\code_change_lines_sum.json
# 已保存成功:./outdata\apache_airflow_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\contributor_email_suffixes.json
# 已保存成功:./outdata\apache_airflow_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\inactive_contributors.json
# 已保存成功:./outdata\apache_airflow_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\issues_and_change_request_active.json
# 已保存成功:./outdata\apache_airflow_issues_closed.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\issues_closed.json
# 已保存成功:./outdata\apache_airflow_issues_new.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\issues_new.json
# 已保存成功:./outdata\apache_airflow_issue_age.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\issue_age.json
# 已保存成功:./outdata\apache_airflow_issue_comments.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\issue_comments.json
# 已保存成功:./outdata\apache_airflow_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\issue_resolution_duration.json
# 已保存成功:./outdata\apache_airflow_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\issue_response_time.json
# 已保存成功:./outdata\apache_airflow_meta.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\meta.json
# 已保存成功:./outdata\apache_airflow_new_contributors.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\new_contributors.json
# 已保存成功:./outdata\apache_airflow_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\new_contributors_detail.json
# 已保存成功:./outdata\apache_airflow_openrank.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\openrank.json
# 已保存成功:./outdata\apache_airflow_participants.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\participants.json
# 已保存成功:./outdata\apache_airflow_stars.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\stars.json
# 已保存成功:./outdata\apache_airflow_technical_fork.csv
# Processed JSON file: ./top_300_metrics\apache\airflow\technical_fork.json
# 已保存成功:./outdata\apache_apisix_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\active_dates_and_times.json
# 已保存成功:./outdata\apache_apisix_activity.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\activity.json
# 已保存成功:./outdata\apache_apisix_activity_details.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\activity_details.json
# 已保存成功:./outdata\apache_apisix_attention.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\attention.json
# 已保存成功:./outdata\apache_apisix_bus_factor.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\bus_factor.json
# 已保存成功:./outdata\apache_apisix_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\bus_factor_detail.json
# 已保存成功:./outdata\apache_apisix_change_requests.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\change_requests.json
# 已保存成功:./outdata\apache_apisix_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\change_requests_accepted.json
# 已保存成功:./outdata\apache_apisix_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\change_requests_reviews.json
# 已保存成功:./outdata\apache_apisix_change_request_age.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\change_request_age.json
# 已保存成功:./outdata\apache_apisix_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\change_request_resolution_duration.json
# 已保存成功:./outdata\apache_apisix_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\change_request_response_time.json
# 已保存成功:./outdata\apache_apisix_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\code_change_lines_add.json
# 已保存成功:./outdata\apache_apisix_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\code_change_lines_remove.json
# 已保存成功:./outdata\apache_apisix_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\code_change_lines_sum.json
# 已保存成功:./outdata\apache_apisix_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\contributor_email_suffixes.json
# 已保存成功:./outdata\apache_apisix_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\inactive_contributors.json
# 已保存成功:./outdata\apache_apisix_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\issues_and_change_request_active.json
# 已保存成功:./outdata\apache_apisix_issues_closed.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\issues_closed.json
# 已保存成功:./outdata\apache_apisix_issues_new.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\issues_new.json
# 已保存成功:./outdata\apache_apisix_issue_age.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\issue_age.json
# 已保存成功:./outdata\apache_apisix_issue_comments.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\issue_comments.json
# 已保存成功:./outdata\apache_apisix_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\issue_resolution_duration.json
# 已保存成功:./outdata\apache_apisix_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\issue_response_time.json
# 已保存成功:./outdata\apache_apisix_meta.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\meta.json
# 已保存成功:./outdata\apache_apisix_new_contributors.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\new_contributors.json
# 已保存成功:./outdata\apache_apisix_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\new_contributors_detail.json
# 已保存成功:./outdata\apache_apisix_openrank.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\openrank.json
# 已保存成功:./outdata\apache_apisix_participants.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\participants.json
# 已保存成功:./outdata\apache_apisix_stars.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\stars.json
# 已保存成功:./outdata\apache_apisix_technical_fork.csv
# Processed JSON file: ./top_300_metrics\apache\apisix\technical_fork.json
# 已保存成功:./outdata\apache_arrow_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\active_dates_and_times.json
# 已保存成功:./outdata\apache_arrow_activity.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\activity.json
# 已保存成功:./outdata\apache_arrow_activity_details.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\activity_details.json
# 已保存成功:./outdata\apache_arrow_attention.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\attention.json
# 已保存成功:./outdata\apache_arrow_bus_factor.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\bus_factor.json
# 已保存成功:./outdata\apache_arrow_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\bus_factor_detail.json
# 已保存成功:./outdata\apache_arrow_change_requests.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\change_requests.json
# 已保存成功:./outdata\apache_arrow_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\change_requests_accepted.json
# 已保存成功:./outdata\apache_arrow_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\change_requests_reviews.json
# 已保存成功:./outdata\apache_arrow_change_request_age.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\change_request_age.json
# 已保存成功:./outdata\apache_arrow_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\change_request_resolution_duration.json
# 已保存成功:./outdata\apache_arrow_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\change_request_response_time.json
# 已保存成功:./outdata\apache_arrow_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\code_change_lines_add.json
# 已保存成功:./outdata\apache_arrow_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\code_change_lines_remove.json
# 已保存成功:./outdata\apache_arrow_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\code_change_lines_sum.json
# 已保存成功:./outdata\apache_arrow_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\contributor_email_suffixes.json
# 已保存成功:./outdata\apache_arrow_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\inactive_contributors.json
# 已保存成功:./outdata\apache_arrow_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\issues_and_change_request_active.json
# 已保存成功:./outdata\apache_arrow_issues_closed.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\issues_closed.json
# 已保存成功:./outdata\apache_arrow_issues_new.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\issues_new.json
# 已保存成功:./outdata\apache_arrow_issue_age.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\issue_age.json
# 已保存成功:./outdata\apache_arrow_issue_comments.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\issue_comments.json
# 已保存成功:./outdata\apache_arrow_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\issue_resolution_duration.json
# 已保存成功:./outdata\apache_arrow_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\issue_response_time.json
# 已保存成功:./outdata\apache_arrow_meta.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\meta.json
# 已保存成功:./outdata\apache_arrow_new_contributors.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\new_contributors.json
# 已保存成功:./outdata\apache_arrow_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\new_contributors_detail.json
# 已保存成功:./outdata\apache_arrow_openrank.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\openrank.json
# 已保存成功:./outdata\apache_arrow_participants.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\participants.json
# 已保存成功:./outdata\apache_arrow_stars.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\stars.json
# 已保存成功:./outdata\apache_arrow_technical_fork.csv
# Processed JSON file: ./top_300_metrics\apache\arrow\technical_fork.json
# 已保存成功:./outdata\apache_beam_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\apache\beam\active_dates_and_times.json
# 已保存成功:./outdata\apache_beam_activity.csv
# Processed JSON file: ./top_300_metrics\apache\beam\activity.json
# 已保存成功:./outdata\apache_beam_activity_details.csv
# Processed JSON file: ./top_300_metrics\apache\beam\activity_details.json
# 已保存成功:./outdata\apache_beam_attention.csv
# Processed JSON file: ./top_300_metrics\apache\beam\attention.json
# 已保存成功:./outdata\apache_beam_bus_factor.csv
# Processed JSON file: ./top_300_metrics\apache\beam\bus_factor.json
# 已保存成功:./outdata\apache_beam_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\apache\beam\bus_factor_detail.json
# 已保存成功:./outdata\apache_beam_change_requests.csv
# Processed JSON file: ./top_300_metrics\apache\beam\change_requests.json
# 已保存成功:./outdata\apache_beam_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\apache\beam\change_requests_accepted.json
# 已保存成功:./outdata\apache_beam_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\apache\beam\change_requests_reviews.json
# 已保存成功:./outdata\apache_beam_change_request_age.csv
# Processed JSON file: ./top_300_metrics\apache\beam\change_request_age.json
# 已保存成功:./outdata\apache_beam_change_request_resolution_duration.csv
# ...
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\code_change_lines_remove.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\code_change_lines_sum.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\contributor_email_suffixes.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\inactive_contributors.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\issues_and_change_request_active.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_issues_closed.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\issues_closed.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_issues_new.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\issues_new.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_issue_age.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\issue_age.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_issue_comments.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\issue_comments.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\issue_resolution_duration.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\issue_response_time.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_meta.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\meta.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_new_contributors.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\new_contributors.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\new_contributors_detail.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_openrank.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\openrank.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_participants.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\participants.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_stars.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\stars.json
# 已保存成功:./outdata\zephyrproject-rtos_zephyr_technical_fork.csv
# Processed JSON file: ./top_300_metrics\zephyrproject-rtos\zephyr\technical_fork.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\active_dates_and_times.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_activity.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\activity.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_activity_details.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\activity_details.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_attention.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\attention.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_bus_factor.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\bus_factor.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\bus_factor_detail.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_change_requests.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\change_requests.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\change_requests_accepted.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\change_requests_reviews.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_change_request_age.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\change_request_age.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\change_request_resolution_duration.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\change_request_response_time.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\code_change_lines_add.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\code_change_lines_remove.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\code_change_lines_sum.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\contributor_email_suffixes.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\inactive_contributors.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\issues_and_change_request_active.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_issues_closed.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\issues_closed.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_issues_new.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\issues_new.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_issue_age.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\issue_age.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_issue_comments.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\issue_comments.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\issue_resolution_duration.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\issue_response_time.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_meta.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\meta.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_new_contributors.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\new_contributors.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\new_contributors_detail.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_openrank.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\openrank.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_participants.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\participants.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_stars.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\stars.json
# 已保存成功:./outdata\zero-to-mastery_start-here-guidelines_technical_fork.csv
# Processed JSON file: ./top_300_metrics\zero-to-mastery\start-here-guidelines\technical_fork.json
# 已保存成功:./outdata\ziglang_zig_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\active_dates_and_times.json
# 已保存成功:./outdata\ziglang_zig_activity.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\activity.json
# 已保存成功:./outdata\ziglang_zig_activity_details.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\activity_details.json
# 已保存成功:./outdata\ziglang_zig_attention.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\attention.json
# 已保存成功:./outdata\ziglang_zig_bus_factor.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\bus_factor.json
# 已保存成功:./outdata\ziglang_zig_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\bus_factor_detail.json
# 已保存成功:./outdata\ziglang_zig_change_requests.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\change_requests.json
# 已保存成功:./outdata\ziglang_zig_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\change_requests_accepted.json
# 已保存成功:./outdata\ziglang_zig_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\change_requests_reviews.json
# 已保存成功:./outdata\ziglang_zig_change_request_age.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\change_request_age.json
# 已保存成功:./outdata\ziglang_zig_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\change_request_resolution_duration.json
# 已保存成功:./outdata\ziglang_zig_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\change_request_response_time.json
# 已保存成功:./outdata\ziglang_zig_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\code_change_lines_add.json
# 已保存成功:./outdata\ziglang_zig_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\code_change_lines_remove.json
# 已保存成功:./outdata\ziglang_zig_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\code_change_lines_sum.json
# 已保存成功:./outdata\ziglang_zig_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\contributor_email_suffixes.json
# 已保存成功:./outdata\ziglang_zig_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\inactive_contributors.json
# 已保存成功:./outdata\ziglang_zig_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\issues_and_change_request_active.json
# 已保存成功:./outdata\ziglang_zig_issues_closed.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\issues_closed.json
# 已保存成功:./outdata\ziglang_zig_issues_new.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\issues_new.json
# 已保存成功:./outdata\ziglang_zig_issue_age.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\issue_age.json
# 已保存成功:./outdata\ziglang_zig_issue_comments.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\issue_comments.json
# 已保存成功:./outdata\ziglang_zig_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\issue_resolution_duration.json
# 已保存成功:./outdata\ziglang_zig_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\issue_response_time.json
# 已保存成功:./outdata\ziglang_zig_meta.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\meta.json
# 已保存成功:./outdata\ziglang_zig_new_contributors.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\new_contributors.json
# 已保存成功:./outdata\ziglang_zig_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\new_contributors_detail.json
# 已保存成功:./outdata\ziglang_zig_openrank.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\openrank.json
# 已保存成功:./outdata\ziglang_zig_participants.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\participants.json
# 已保存成功:./outdata\ziglang_zig_stars.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\stars.json
# 已保存成功:./outdata\ziglang_zig_technical_fork.csv
# Processed JSON file: ./top_300_metrics\ziglang\zig\technical_fork.json
# 已保存成功:./outdata\zulip_zulip_active_dates_and_times.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\active_dates_and_times.json
# 已保存成功:./outdata\zulip_zulip_activity.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\activity.json
# 已保存成功:./outdata\zulip_zulip_activity_details.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\activity_details.json
# 已保存成功:./outdata\zulip_zulip_attention.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\attention.json
# 已保存成功:./outdata\zulip_zulip_bus_factor.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\bus_factor.json
# 已保存成功:./outdata\zulip_zulip_bus_factor_detail.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\bus_factor_detail.json
# 已保存成功:./outdata\zulip_zulip_change_requests.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\change_requests.json
# 已保存成功:./outdata\zulip_zulip_change_requests_accepted.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\change_requests_accepted.json
# 已保存成功:./outdata\zulip_zulip_change_requests_reviews.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\change_requests_reviews.json
# 已保存成功:./outdata\zulip_zulip_change_request_age.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\change_request_age.json
# 已保存成功:./outdata\zulip_zulip_change_request_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\change_request_resolution_duration.json
# 已保存成功:./outdata\zulip_zulip_change_request_response_time.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\change_request_response_time.json
# 已保存成功:./outdata\zulip_zulip_code_change_lines_add.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\code_change_lines_add.json
# 已保存成功:./outdata\zulip_zulip_code_change_lines_remove.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\code_change_lines_remove.json
# 已保存成功:./outdata\zulip_zulip_code_change_lines_sum.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\code_change_lines_sum.json
# 已保存成功:./outdata\zulip_zulip_contributor_email_suffixes.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\contributor_email_suffixes.json
# 已保存成功:./outdata\zulip_zulip_inactive_contributors.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\inactive_contributors.json
# 已保存成功:./outdata\zulip_zulip_issues_and_change_request_active.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\issues_and_change_request_active.json
# 已保存成功:./outdata\zulip_zulip_issues_closed.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\issues_closed.json
# 已保存成功:./outdata\zulip_zulip_issues_new.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\issues_new.json
# 已保存成功:./outdata\zulip_zulip_issue_age.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\issue_age.json
# 已保存成功:./outdata\zulip_zulip_issue_comments.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\issue_comments.json
# 已保存成功:./outdata\zulip_zulip_issue_resolution_duration.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\issue_resolution_duration.json
# 已保存成功:./outdata\zulip_zulip_issue_response_time.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\issue_response_time.json
# 已保存成功:./outdata\zulip_zulip_meta.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\meta.json
# 已保存成功:./outdata\zulip_zulip_new_contributors.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\new_contributors.json
# 已保存成功:./outdata\zulip_zulip_new_contributors_detail.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\new_contributors_detail.json
# 已保存成功:./outdata\zulip_zulip_openrank.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\openrank.json
# 已保存成功:./outdata\zulip_zulip_participants.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\participants.json
# 已保存成功:./outdata\zulip_zulip_stars.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\stars.json
# 已保存成功:./outdata\zulip_zulip_technical_fork.csv
# Processed JSON file: ./top_300_metrics\zulip\zulip\technical_fork.json
