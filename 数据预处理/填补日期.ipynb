# %%
import os
import pandas as pd 

def load_reference_columns(reference_file_path,column_name='指标名称'):
    df_ref=pd.read_csv(reference_file_path)
    if column_name in df_ref.columns:
        return df_ref[column_name]

def process_single_file(input_file_path, reference_series, output_dir):
    try:
        # 加载CSV文件
        df = pd.read_csv(input_file_path)
        # 获取当前文件的列名
        column_name='指标名称'
        # 对比并补全缺失的列
        if column_name not in df.columns:
            # 如果当前文件不存在该列，则该列填充为NaN
            df[column_name]=float('nan')
            
        # 确保日期格式一致
        reference_series = pd.to_datetime(reference_series, format='%Y-%m').dt.strftime('%Y-%m')
        df[column_name] = pd.to_datetime(df[column_name], format='%Y-%m', errors='coerce').dt.strftime('%Y-%m')

        # 创建一个完整的日期索引以检查缺失的日期
        complete_dates =pd.DataFrame({'指标名称': reference_series.unique()})
        df_complete=pd.merge(complete_dates,df,on='指标名称',how='left')
        # 构建输出文件路径
        base_name=os.path.basename(input_file_path)
        output_file_path=os.path.join(output_dir, base_name)

        # 保存更新后的数据到新的CSV文件
        df_complete.to_csv(output_file_path, index=False)

        print(f"已处理并保存到 {output_file_path}")

    except Exception as e:
        print(f"处理文件 {input_file_path} 时出错: {e}")

def find_matching_active_file(base_dir, input_file_path):
    dir_path = os.path.dirname(input_file_path)
    file_name=os.path.basename(input_file_path)
    parts=file_name.split('_',2)
    file_prefix=parts[0]+'_'+parts[1]
    for root, dirs, files in os.walk(dir_path):
        for file in files: 
            if file.endswith('active_dates_and_times.csv') and file.startswith(file_prefix): # 匹配寻找对应的时间基准
                return os.path.join(root, file)
    return None

def process_all_files(base_dir,output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, dirs, files in os.walk(base_dir):
        for file in files:
             if file.endswith('.csv') and not file.endswith('active_dates_and_times.csv'):
                input_file_path=os.path.join(root, file)
                # 查找对应的 active_dates_and_times.csv 文件
                matching_active_file=find_matching_active_file(base_dir, input_file_path)
                if matching_active_file:
                    # 加载参考文件的列名
                    reference_series=load_reference_columns(matching_active_file)
                    # 处理单个文件
                    process_single_file(input_file_path, reference_series, output_dir)
                else:
                    print(f"警告: 没有找到与 {input_file_path} 对应的 active_dates_and_times.csv 文件")


base_dir='./outputdata 原数据'
output_dir='./add 仅填补日期 无补0'
process_all_files(base_dir,output_dir)
# Out:
# 已处理并保存到 ./add\AdguardTeam_AdguardFilters_contributor.csv
# 已处理并保存到 ./add\airbytehq_airbyte_contributor.csv
# 已处理并保存到 ./add\alibaba_nacos_contributor.csv
# 已处理并保存到 ./add\angular_angular_contributor.csv
# 已处理并保存到 ./add\angular_components_contributor.csv
# 已处理并保存到 ./add\ankidroid_Anki-Android_contributor.csv
# 已处理并保存到 ./add\ansible_ansible_contributor.csv
# 已处理并保存到 ./add\ant-design_ant-design_contributor.csv
# 已处理并保存到 ./add\apache_airflow_contributor.csv
# 已处理并保存到 ./add\apache_apisix_contributor.csv
# 已处理并保存到 ./add\apache_arrow_contributor.csv
# 已处理并保存到 ./add\apache_beam_contributor.csv
# 已处理并保存到 ./add\apache_dolphinscheduler_contributor.csv
# 已处理并保存到 ./add\apache_doris_contributor.csv
# 已处理并保存到 ./add\apache_flink_contributor.csv
# 已处理并保存到 ./add\apache_hudi_contributor.csv
# 已处理并保存到 ./add\apache_iceberg_contributor.csv
# 已处理并保存到 ./add\apache_pulsar_contributor.csv
# 已处理并保存到 ./add\apache_shardingsphere_contributor.csv
# 已处理并保存到 ./add\apache_spark_contributor.csv
# 已处理并保存到 ./add\apache_superset_contributor.csv
# 已处理并保存到 ./add\apache_tvm_contributor.csv
# 已处理并保存到 ./add\apple_swift_contributor.csv
# 已处理并保存到 ./add\appsmithorg_appsmith_contributor.csv
# 已处理并保存到 ./add\archway-network_testnets_contributor.csv
# 已处理并保存到 ./add\ArduPilot_ardupilot_contributor.csv
# 已处理并保存到 ./add\argoproj_argo-cd_contributor.csv
# 已处理并保存到 ./add\AUTOMATIC1111_stable-diffusion-webui_contributor.csv
# 已处理并保存到 ./add\Automattic_jetpack_contributor.csv
# 已处理并保存到 ./add\Automattic_wp-calypso_contributor.csv
# 已处理并保存到 ./add\aws-amplify_amplify-cli_contributor.csv
# 已处理并保存到 ./add\aws_aws-cdk_contributor.csv
# 已处理并保存到 ./add\azerothcore_azerothcore-wotlk_contributor.csv
# 已处理并保存到 ./add\Azure_azure-cli_contributor.csv
# 已处理并保存到 ./add\Azure_azure-powershell_contributor.csv
# 已处理并保存到 ./add\Azure_azure-rest-api-specs_contributor.csv
# 已处理并保存到 ./add\Azure_azure-sdk-for-java_contributor.csv
# 已处理并保存到 ./add\Azure_azure-sdk-for-js_contributor.csv
# 已处理并保存到 ./add\Azure_azure-sdk-for-net_contributor.csv
# 已处理并保存到 ./add\Azure_azure-sdk-for-python_contributor.csv
# 已处理并保存到 ./add\backstage_backstage_contributor.csv
# 已处理并保存到 ./add\bevyengine_bevy_contributor.csv
# 已处理并保存到 ./add\bioconda_bioconda-recipes_contributor.csv
# 已处理并保存到 ./add\bitcoin_bitcoin_contributor.csv
# 已处理并保存到 ./add\bitnami_charts_contributor.csv
# 已处理并保存到 ./add\brave_brave-browser_contributor.csv
# 已处理并保存到 ./add\brave_brave-core_contributor.csv
# 已处理并保存到 ./add\ccxt_ccxt_contributor.csv
# 已处理并保存到 ./add\ceph_ceph_contributor.csv
# 已处理并保存到 ./add\Chia-Network_chia-blockchain_contributor.csv
# 已处理并保存到 ./add\cilium_cilium_contributor.csv
# 已处理并保存到 ./add\CleverRaven_Cataclysm-DDA_contributor.csv
# 已处理并保存到 ./add\ClickHouse_ClickHouse_contributor.csv
# 已处理并保存到 ./add\cloudflare_cloudflare-docs_contributor.csv
# 已处理并保存到 ./add\cms-sw_cmssw_contributor.csv
# 已处理并保存到 ./add\cockroachdb_cockroach_contributor.csv
# 已处理并保存到 ./add\conan-io_conan-center-index_contributor.csv
# 已处理并保存到 ./add\conda-forge_staged-recipes_contributor.csv
# 已处理并保存到 ./add\containers_podman_contributor.csv
# 已处理并保存到 ./add\coolsnowwolf_lede_contributor.csv
# 已处理并保存到 ./add\cypress-io_cypress_contributor.csv
# 已处理并保存到 ./add\darktable-org_darktable_contributor.csv
# 已处理并保存到 ./add\DataDog_datadog-agent_contributor.csv
# 已处理并保存到 ./add\dbeaver_dbeaver_contributor.csv
# 已处理并保存到 ./add\DefinitelyTyped_DefinitelyTyped_contributor.csv
# 已处理并保存到 ./add\demisto_content_contributor.csv
# 已处理并保存到 ./add\denoland_deno_contributor.csv
# 已处理并保存到 ./add\department-of-veterans-affairs_va.gov-team_contributor.csv
# 已处理并保存到 ./add\desktop_desktop_contributor.csv
# 已处理并保存到 ./add\directus_directus_contributor.csv
# 已处理并保存到 ./add\docker_docs_contributor.csv
# 已处理并保存到 ./add\dotnet_AspNetCore.Docs_contributor.csv
# 已处理并保存到 ./add\dotnet_aspnetcore_contributor.csv
# 已处理并保存到 ./add\dotnet_docs_contributor.csv
# 已处理并保存到 ./add\dotnet_efcore_contributor.csv
# 已处理并保存到 ./add\dotnet_maui_contributor.csv
# 已处理并保存到 ./add\dotnet_roslyn_contributor.csv
# 已处理并保存到 ./add\dotnet_runtime_contributor.csv
# 已处理并保存到 ./add\education_GitHubGraduation-2022_contributor.csv
# 已处理并保存到 ./add\elastic_elasticsearch_contributor.csv
# 已处理并保存到 ./add\elastic_kibana_contributor.csv
# 已处理并保存到 ./add\electron_electron_contributor.csv
# 已处理并保存到 ./add\element-fi_elf-council-frontend_contributor.csv
# 已处理并保存到 ./add\element-plus_element-plus_contributor.csv
# 已处理并保存到 ./add\elementor_elementor_contributor.csv
# 已处理并保存到 ./add\envoyproxy_envoy_contributor.csv
# 已处理并保存到 ./add\espressif_esp-idf_contributor.csv
# 已处理并保存到 ./add\ethereum_ethereum-org-website_contributor.csv
# 已处理并保存到 ./add\Expensify_App_contributor.csv
# 已处理并保存到 ./add\expo_expo_contributor.csv
# 已处理并保存到 ./add\facebook_react-native_contributor.csv
# 已处理并保存到 ./add\facebook_react_contributor.csv
# 已处理并保存到 ./add\filecoin-project_filecoin-plus-large-datasets_contributor.csv
# 已处理并保存到 ./add\files-community_Files_contributor.csv
# 已处理并保存到 ./add\firebase_firebase-android-sdk_contributor.csv
# 已处理并保存到 ./add\firebase_flutterfire_contributor.csv
# 已处理并保存到 ./add\firstcontributions_first-contributions_contributor.csv
# 已处理并保存到 ./add\flathub_flathub_contributor.csv
# 已处理并保存到 ./add\flutter_engine_contributor.csv
# 已处理并保存到 ./add\flutter_flutter_contributor.csv
# 已处理并保存到 ./add\flutter_plugins_contributor.csv
# 已处理并保存到 ./add\flybywiresim_a32nx_contributor.csv
# 已处理并保存到 ./add\freddier_hyperblog_contributor.csv
# 已处理并保存到 ./add\gatsbyjs_gatsby_contributor.csv
# 已处理并保存到 ./add\gentoo_gentoo_contributor.csv
# 已处理并保存到 ./add\getsentry_sentry_contributor.csv
# 已处理并保存到 ./add\github_codeql_contributor.csv
# 已处理并保存到 ./add\github_docs_contributor.csv
# 已处理并保存到 ./add\gitpod-io_gitpod_contributor.csv
# 已处理并保存到 ./add\go-gitea_gitea_contributor.csv
# 已处理并保存到 ./add\godotengine_godot_contributor.csv
# 已处理并保存到 ./add\golang_go_contributor.csv
# 已处理并保存到 ./add\google-test_signclav2-probe-repo_contributor.csv
# 已处理并保存到 ./add\GoogleChrome_developer.chrome.com_contributor.csv
# 已处理并保存到 ./add\google_it-cert-automation-practice_contributor.csv
# 已处理并保存到 ./add\gradle_gradle_contributor.csv
# 已处理并保存到 ./add\grafana_grafana_contributor.csv
# 已处理并保存到 ./add\grafana_loki_contributor.csv
# 已处理并保存到 ./add\gravitational_teleport_contributor.csv
# 已处理并保存到 ./add\grpc_grpc_contributor.csv
# 已处理并保存到 ./add\hashicorp_terraform-provider-aws_contributor.csv
# 已处理并保存到 ./add\hashicorp_terraform-provider-azurerm_contributor.csv
# 已处理并保存到 ./add\hashicorp_vault_contributor.csv
# 已处理并保存到 ./add\helium_denylist_contributor.csv
# 已处理并保存到 ./add\helix-editor_helix_contributor.csv
# 已处理并保存到 ./add\home-assistant_core_contributor.csv
# 已处理并保存到 ./add\home-assistant_frontend_contributor.csv
# 已处理并保存到 ./add\home-assistant_home-assistant.io_contributor.csv
# 已处理并保存到 ./add\Homebrew_homebrew-cask_contributor.csv
# 已处理并保存到 ./add\Homebrew_homebrew-core_contributor.csv
# 已处理并保存到 ./add\huggingface_transformers_contributor.csv
# 已处理并保存到 ./add\idsb3t1_KEEP-pipeline-tests-resources_contributor.csv
# 已处理并保存到 ./add\influxdata_telegraf_contributor.csv
# 已处理并保存到 ./add\IntelRealSense_librealsense_contributor.csv
# 已处理并保存到 ./add\istio_istio_contributor.csv
# 已处理并保存到 ./add\JacksonKearl_testissues_contributor.csv
# 已处理并保存到 ./add\JetBrains_swot_contributor.csv
# 已处理并保存到 ./add\jitsi_jitsi-meet_contributor.csv
# 已处理并保存到 ./add\jlord_patchwork_contributor.csv
# 已处理并保存到 ./add\joomla_joomla-cms_contributor.csv
# 已处理并保存到 ./add\JuliaLang_julia_contributor.csv
# 已处理并保存到 ./add\JuliaRegistries_General_contributor.csv
# 已处理并保存到 ./add\Kaiserreich_Kaiserreich-4_contributor.csv
# 已处理并保存到 ./add\keycloak_keycloak_contributor.csv
# 已处理并保存到 ./add\Koenkk_zigbee2mqtt_contributor.csv
# 已处理并保存到 ./add\kubernetes_kubernetes_contributor.csv
# 已处理并保存到 ./add\kubernetes_minikube_contributor.csv
# 已处理并保存到 ./add\kubernetes_test-infra_contributor.csv
# 已处理并保存到 ./add\kubernetes_website_contributor.csv
# 已处理并保存到 ./add\kubevirt_kubevirt_contributor.csv
# 已处理并保存到 ./add\laravel_framework_contributor.csv
# 已处理并保存到 ./add\leanprover-community_mathlib_contributor.csv
# 已处理并保存到 ./add\LeetCode-Feedback_LeetCode-Feedback_contributor.csv
# 已处理并保存到 ./add\lensapp_lens_contributor.csv
# 已处理并保存到 ./add\Lightning-AI_lightning_contributor.csv
# 已处理并保存到 ./add\llvm_llvm-project_contributor.csv
# 已处理并保存到 ./add\logseq_logseq_contributor.csv
# 已处理并保存到 ./add\macports_macports-ports_contributor.csv
# 已处理并保存到 ./add\magento_magento2_contributor.csv
# 已处理并保存到 ./add\MarlinFirmware_Marlin_contributor.csv
# 已处理并保存到 ./add\mastodon_mastodon_contributor.csv
# 已处理并保存到 ./add\matplotlib_matplotlib_contributor.csv
# 已处理并保存到 ./add\matrix-org_synapse_contributor.csv
# 已处理并保存到 ./add\mattermost_mattermost-webapp_contributor.csv
# 已处理并保存到 ./add\mdn_content_contributor.csv
# 已处理并保存到 ./add\mdn_translated-content_contributor.csv
# 已处理并保存到 ./add\metabase_metabase_contributor.csv
# 已处理并保存到 ./add\MetaMask_eth-phishing-detect_contributor.csv
# 已处理并保存到 ./add\MetaMask_metamask-extension_contributor.csv
# 已处理并保存到 ./add\metersphere_metersphere_contributor.csv
# 已处理并保存到 ./add\MicrosoftDocs_azure-docs_contributor.csv
# 已处理并保存到 ./add\MicrosoftDocs_microsoft-365-docs_contributor.csv
# 已处理并保存到 ./add\MicrosoftDocs_msteams-docs_contributor.csv
# 已处理并保存到 ./add\microsoftgraph_microsoft-graph-docs_contributor.csv
# 已处理并保存到 ./add\microsoft_azuredatastudio_contributor.csv
# 已处理并保存到 ./add\microsoft_fluentui_contributor.csv
# 已处理并保存到 ./add\microsoft_onnxruntime_contributor.csv
# 已处理并保存到 ./add\microsoft_playwright_contributor.csv
# 已处理并保存到 ./add\microsoft_PowerToys_contributor.csv
# 已处理并保存到 ./add\microsoft_terminal_contributor.csv
# 已处理并保存到 ./add\microsoft_TypeScript_contributor.csv
# 已处理并保存到 ./add\microsoft_vcpkg_contributor.csv
# 已处理并保存到 ./add\microsoft_vscode-jupyter_contributor.csv
# 已处理并保存到 ./add\microsoft_vscode_contributor.csv
# 已处理并保存到 ./add\microsoft_winget-pkgs_contributor.csv
# 已处理并保存到 ./add\microsoft_WSL_contributor.csv
# 已处理并保存到 ./add\mlflow_mlflow_contributor.csv
# 已处理并保存到 ./add\mozilla-mobile_fenix_contributor.csv
# 已处理并保存到 ./add\mrdoob_three.js_contributor.csv
# 已处理并保存到 ./add\mui_material-ui_contributor.csv
# 已处理并保存到 ./add\mui_mui-x_contributor.csv
# 已处理并保存到 ./add\neovim_neovim_contributor.csv
# 已处理并保存到 ./add\newrelic_docs-website_contributor.csv
# 已处理并保存到 ./add\nextcloud_desktop_contributor.csv
# 已处理并保存到 ./add\nextcloud_server_contributor.csv
# 已处理并保存到 ./add\NixOS_nixpkgs_contributor.csv
# 已处理并保存到 ./add\nodejs_node_contributor.csv
# 已处理并保存到 ./add\nrfconnect_sdk-nrf_contributor.csv
# 已处理并保存到 ./add\nrwl_nx_contributor.csv
# 已处理并保存到 ./add\nuxt_framework_contributor.csv
# 已处理并保存到 ./add\o3de_o3de_contributor.csv
# 已处理并保存到 ./add\obsproject_obs-studio_contributor.csv
# 已处理并保存到 ./add\odoo_odoo_contributor.csv
# 已处理并保存到 ./add\open-mmlab_mmdetection_contributor.csv
# 已处理并保存到 ./add\open-telemetry_opentelemetry-collector-contrib_contributor.csv
# 已处理并保存到 ./add\OpenAPITools_openapi-generator_contributor.csv
# 已处理并保存到 ./add\opencv_opencv_contributor.csv
# 已处理并保存到 ./add\openhab_openhab-addons_contributor.csv
# 已处理并保存到 ./add\openjdk_jdk_contributor.csv
# 已处理并保存到 ./add\openjournals_joss-reviews_contributor.csv
# 已处理并保存到 ./add\openshift_openshift-docs_contributor.csv
# 已处理并保存到 ./add\openshift_release_contributor.csv
# 已处理并保存到 ./add\openssl_openssl_contributor.csv
# 已处理并保存到 ./add\openvinotoolkit_openvino_contributor.csv
# 已处理并保存到 ./add\openwrt_openwrt_contributor.csv
# 已处理并保存到 ./add\oppia_oppia_contributor.csv
# 已处理并保存到 ./add\PaddlePaddle_PaddleOCR_contributor.csv
# 已处理并保存到 ./add\PaddlePaddle_Paddle_contributor.csv
# 已处理并保存到 ./add\pandas-dev_pandas_contributor.csv
# 已处理并保存到 ./add\php_php-src_contributor.csv
# 已处理并保存到 ./add\pingcap_tidb_contributor.csv
# 已处理并保存到 ./add\PixelExperience_android-issues_contributor.csv
# 已处理并保存到 ./add\postmanlabs_postman-app-support_contributor.csv
# 已处理并保存到 ./add\PowerShell_PowerShell_contributor.csv
# 已处理并保存到 ./add\ppy_osu_contributor.csv
# 已处理并保存到 ./add\PrestaShop_PrestaShop_contributor.csv
# 已处理并保存到 ./add\prisma_prisma_contributor.csv
# 已处理并保存到 ./add\project-chip_connectedhomeip_contributor.csv
# 已处理并保存到 ./add\prusa3d_PrusaSlicer_contributor.csv
# 已处理并保存到 ./add\python_cpython_contributor.csv
# 已处理并保存到 ./add\pytorch_pytorch_contributor.csv
# 已处理并保存到 ./add\qbittorrent_qBittorrent_contributor.csv
# 已处理并保存到 ./add\qgis_QGIS_contributor.csv
# 已处理并保存到 ./add\qmk_qmk_contributor.csv
# 已处理并保存到 ./add\quarkusio_quarkus_contributor.csv
# 已处理并保存到 ./add\rails_rails_contributor.csv
# 已处理并保存到 ./add\rancher_rancher_contributor.csv
# 已处理并保存到 ./add\rapid7_metasploit-framework_contributor.csv
# 已处理并保存到 ./add\ray-project_ray_contributor.csv
# 已处理并保存到 ./add\raycast_extensions_contributor.csv
# 已处理并保存到 ./add\redis_redis_contributor.csv
# 已处理并保存到 ./add\Regalis11_Barotrauma_contributor.csv
# 已处理并保存到 ./add\remix-run_remix_contributor.csv
# 已处理并保存到 ./add\renovatebot_renovate_contributor.csv
# 已处理并保存到 ./add\RocketChat_Rocket.Chat_contributor.csv
# 已处理并保存到 ./add\RPCS3_rpcs3_contributor.csv
# 已处理并保存到 ./add\rstudio_rstudio_contributor.csv
# 已处理并保存到 ./add\ruffle-rs_ruffle_contributor.csv
# 已处理并保存到 ./add\rust-lang_rust_contributor.csv
# 已处理并保存到 ./add\scikit-learn_scikit-learn_contributor.csv
# 已处理并保存到 ./add\scipy_scipy_contributor.csv
# 已处理并保存到 ./add\section-engineering-education_engineering-education_contributor.csv
# 已处理并保存到 ./add\SerenityOS_serenity_contributor.csv
# 已处理并保存到 ./add\ShadowMario_FNF-PsychEngine_contributor.csv
# 已处理并保存到 ./add\Skyrat-SS13_Skyrat-tg_contributor.csv
# 已处理并保存到 ./add\solana-labs_solana_contributor.csv
# 已处理并保存到 ./add\solana-labs_token-list_contributor.csv
# 已处理并保存到 ./add\sourcegraph_sourcegraph_contributor.csv
# 已处理并保存到 ./add\spack_spack_contributor.csv
# 已处理并保存到 ./add\spyder-ide_spyder_contributor.csv
# 已处理并保存到 ./add\storybookjs_storybook_contributor.csv
# 已处理并保存到 ./add\strapi_strapi_contributor.csv
# 已处理并保存到 ./add\sveltejs_kit_contributor.csv
# 已处理并保存到 ./add\symfony_symfony_contributor.csv
# 已处理并保存到 ./add\systemd_systemd_contributor.csv
# 已处理并保存到 ./add\tachiyomiorg_tachiyomi-extensions_contributor.csv
# 已处理并保存到 ./add\tachiyomiorg_tachiyomi_contributor.csv
# 已处理并保存到 ./add\tailscale_tailscale_contributor.csv
# 已处理并保存到 ./add\taosdata_TDengine_contributor.csv
# 已处理并保存到 ./add\taozhiyu_TyProAction_contributor.csv
# 已处理并保存到 ./add\TeamNewPipe_NewPipe_contributor.csv
# 已处理并保存到 ./add\tensorflow_tensorflow_contributor.csv
# 已处理并保存到 ./add\termux_termux-packages_contributor.csv
# 已处理并保存到 ./add\tgstation_tgstation_contributor.csv
# 已处理并保存到 ./add\TP-Lab_tokens_contributor.csv
# 已处理并保存到 ./add\trinodb_trino_contributor.csv
# 已处理并保存到 ./add\trustwallet_assets_contributor.csv
# 已处理并保存到 ./add\type-challenges_type-challenges_contributor.csv
# 已处理并保存到 ./add\uBlockOrigin_uAssets_contributor.csv
# 已处理并保存到 ./add\Ultimaker_Cura_contributor.csv
# 已处理并保存到 ./add\ultralytics_yolov5_contributor.csv
# 已处理并保存到 ./add\unifyai_ivy_contributor.csv
# 已处理并保存到 ./add\ValveSoftware_Dota2-Gameplay_contributor.csv
# 已处理并保存到 ./add\ValveSoftware_Proton_contributor.csv
# 已处理并保存到 ./add\vectordotdev_vector_contributor.csv
# 已处理并保存到 ./add\vercel_next.js_contributor.csv
# 已处理并保存到 ./add\vitejs_vite_contributor.csv
# 已处理并保存到 ./add\void-linux_void-packages_contributor.csv
# 已处理并保存到 ./add\webcompat_web-bugs_contributor.csv
# 已处理并保存到 ./add\wjz304_Redpill_contributor.csv
# 已处理并保存到 ./add\woocommerce_woocommerce_contributor.csv
# 已处理并保存到 ./add\WordPress_gutenberg_contributor.csv
# 已处理并保存到 ./add\xamarin_xamarin-macios_contributor.csv
# 已处理并保存到 ./add\xbmc_xbmc_contributor.csv
# 已处理并保存到 ./add\yt-dlp_yt-dlp_contributor.csv
# 已处理并保存到 ./add\yuzu-emu_yuzu_contributor.csv
# 已处理并保存到 ./add\zephyrproject-rtos_zephyr_contributor.csv
# 已处理并保存到 ./add\zero-to-mastery_start-here-guidelines_contributor.csv
# 已处理并保存到 ./add\ziglang_zig_contributor.csv
# 已处理并保存到 ./add\zulip_zulip_contributor.csv
