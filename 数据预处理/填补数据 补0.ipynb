# %%
import os
import pandas as pd

def process_all_files(base_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if  file.endswith('contributor.csv') or file.endswith('new_contributors.csv') or file.endswith('inactive_contributors.csv') or file.endswith('change_requests.csv') or file.endswith('change_requests_accepted.csv') or file.endswith('change_requests_reviews.csv') or file.endswith('issues_new.csv') or file.endswith('issues_closed.csv') or file.endswith('code_change_lines_add.csv') or file.endswith('code_change_lines_remove.csv') or file.endswith('code_change_lines_sum.csv') or file.endswith('issue_comments.csv') or file.endswith('bus_factor.csv'):
                input_file_path = os.path.join(root, file)
                # 处理单个文件
                df=pd.read_csv(input_file_path)
                df['指标值']=df['指标值'].fillna(0)

                base_name = os.path.basename(input_file_path)
                output_file_path = os.path.join(output_dir, base_name)

                df.to_csv(output_file_path, index=False)

                print(f"已处理并保存到 {output_file_path}")

# 指定基础目录和输出目录
base_dir = './add 仅填补日期 无补0'
output_dir = './填补数据 补0+KNN近邻+问题变更等'
process_all_files(base_dir, output_dir)
# Out:
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AdguardTeam_AdguardFilters_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\airbytehq_airbyte_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\alibaba_nacos_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_angular_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\angular_components_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ankidroid_Anki-Android_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ansible_ansible_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ant-design_ant-design_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_airflow_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_apisix_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_arrow_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_beam_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_dolphinscheduler_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_doris_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_flink_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_hudi_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_iceberg_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_pulsar_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_shardingsphere_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_spark_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_superset_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apache_tvm_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\apple_swift_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\appsmithorg_appsmith_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\archway-network_testnets_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ArduPilot_ardupilot_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\argoproj_argo-cd_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\AUTOMATIC1111_stable-diffusion-webui_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_jetpack_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Automattic_wp-calypso_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws-amplify_amplify-cli_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\aws_aws-cdk_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\azerothcore_azerothcore-wotlk_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-cli_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-powershell_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-rest-api-specs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-java_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-js_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-net_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Azure_azure-sdk-for-python_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\backstage_backstage_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bevyengine_bevy_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bioconda_bioconda-recipes_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitcoin_bitcoin_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\bitnami_charts_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-browser_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\brave_brave-core_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ccxt_ccxt_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ceph_ceph_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Chia-Network_chia-blockchain_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cilium_cilium_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\CleverRaven_Cataclysm-DDA_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ClickHouse_ClickHouse_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cloudflare_cloudflare-docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cms-sw_cmssw_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cockroachdb_cockroach_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\conan-io_conan-center-index_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\conda-forge_staged-recipes_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\containers_podman_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\coolsnowwolf_lede_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\cypress-io_cypress_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\darktable-org_darktable_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\DataDog_datadog-agent_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dbeaver_dbeaver_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\DefinitelyTyped_DefinitelyTyped_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\demisto_content_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\denoland_deno_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\department-of-veterans-affairs_va.gov-team_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\desktop_desktop_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\directus_directus_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\docker_docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dotnet_AspNetCore.Docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dotnet_aspnetcore_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dotnet_docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dotnet_efcore_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dotnet_maui_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dotnet_roslyn_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\dotnet_runtime_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\education_GitHubGraduation-2022_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\elastic_elasticsearch_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\elastic_kibana_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\electron_electron_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\element-fi_elf-council-frontend_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\element-plus_element-plus_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\elementor_elementor_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\envoyproxy_envoy_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\espressif_esp-idf_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ethereum_ethereum-org-website_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Expensify_App_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\expo_expo_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\facebook_react-native_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\facebook_react_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\filecoin-project_filecoin-plus-large-datasets_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\files-community_Files_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\firebase_firebase-android-sdk_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\firebase_flutterfire_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\firstcontributions_first-contributions_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\flathub_flathub_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\flutter_engine_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\flutter_flutter_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\flutter_plugins_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\flybywiresim_a32nx_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\freddier_hyperblog_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\gatsbyjs_gatsby_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\gentoo_gentoo_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\getsentry_sentry_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\github_codeql_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\github_docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\gitpod-io_gitpod_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\go-gitea_gitea_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\godotengine_godot_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\golang_go_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\google-test_signclav2-probe-repo_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\GoogleChrome_developer.chrome.com_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\google_it-cert-automation-practice_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\gradle_gradle_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\grafana_grafana_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\grafana_loki_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\gravitational_teleport_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\grpc_grpc_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\hashicorp_terraform-provider-aws_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\hashicorp_terraform-provider-azurerm_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\hashicorp_vault_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\helium_denylist_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\helix-editor_helix_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\home-assistant_core_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\home-assistant_frontend_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\home-assistant_home-assistant.io_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Homebrew_homebrew-cask_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Homebrew_homebrew-core_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\huggingface_transformers_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\idsb3t1_KEEP-pipeline-tests-resources_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\influxdata_telegraf_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\IntelRealSense_librealsense_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\istio_istio_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\JacksonKearl_testissues_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\JetBrains_swot_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\jitsi_jitsi-meet_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\jlord_patchwork_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\joomla_joomla-cms_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\JuliaLang_julia_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\JuliaRegistries_General_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Kaiserreich_Kaiserreich-4_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\keycloak_keycloak_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Koenkk_zigbee2mqtt_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\kubernetes_kubernetes_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\kubernetes_minikube_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\kubernetes_test-infra_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\kubernetes_website_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\kubevirt_kubevirt_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\laravel_framework_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\leanprover-community_mathlib_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\LeetCode-Feedback_LeetCode-Feedback_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\lensapp_lens_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Lightning-AI_lightning_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\llvm_llvm-project_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\logseq_logseq_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\macports_macports-ports_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\magento_magento2_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\MarlinFirmware_Marlin_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mastodon_mastodon_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\matplotlib_matplotlib_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\matrix-org_synapse_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mattermost_mattermost-webapp_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mdn_content_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mdn_translated-content_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\metabase_metabase_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\MetaMask_eth-phishing-detect_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\MetaMask_metamask-extension_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\metersphere_metersphere_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\MicrosoftDocs_azure-docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\MicrosoftDocs_microsoft-365-docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\MicrosoftDocs_msteams-docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoftgraph_microsoft-graph-docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_azuredatastudio_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_fluentui_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_onnxruntime_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_playwright_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_PowerToys_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_terminal_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_TypeScript_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_vcpkg_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_vscode-jupyter_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_vscode_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_winget-pkgs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\microsoft_WSL_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mlflow_mlflow_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mozilla-mobile_fenix_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mrdoob_three.js_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mui_material-ui_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\mui_mui-x_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\neovim_neovim_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\newrelic_docs-website_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\nextcloud_desktop_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\nextcloud_server_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\NixOS_nixpkgs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\nodejs_node_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\nrfconnect_sdk-nrf_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\nrwl_nx_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\nuxt_framework_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\o3de_o3de_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\obsproject_obs-studio_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\odoo_odoo_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\open-mmlab_mmdetection_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\open-telemetry_opentelemetry-collector-contrib_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\OpenAPITools_openapi-generator_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\opencv_opencv_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openhab_openhab-addons_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openjdk_jdk_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openjournals_joss-reviews_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openshift_openshift-docs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openshift_release_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openssl_openssl_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openvinotoolkit_openvino_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\openwrt_openwrt_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\oppia_oppia_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\PaddlePaddle_PaddleOCR_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\PaddlePaddle_Paddle_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\pandas-dev_pandas_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\php_php-src_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\pingcap_tidb_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\PixelExperience_android-issues_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\postmanlabs_postman-app-support_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\PowerShell_PowerShell_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ppy_osu_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\PrestaShop_PrestaShop_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\prisma_prisma_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\project-chip_connectedhomeip_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\prusa3d_PrusaSlicer_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\python_cpython_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\pytorch_pytorch_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\qbittorrent_qBittorrent_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\qgis_QGIS_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\qmk_qmk_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\quarkusio_quarkus_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\rails_rails_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\rancher_rancher_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\rapid7_metasploit-framework_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ray-project_ray_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\raycast_extensions_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\redis_redis_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Regalis11_Barotrauma_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\remix-run_remix_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\renovatebot_renovate_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\RocketChat_Rocket.Chat_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\RPCS3_rpcs3_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\rstudio_rstudio_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ruffle-rs_ruffle_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\rust-lang_rust_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\scikit-learn_scikit-learn_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\scipy_scipy_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\section-engineering-education_engineering-education_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\SerenityOS_serenity_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ShadowMario_FNF-PsychEngine_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Skyrat-SS13_Skyrat-tg_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\solana-labs_solana_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\solana-labs_token-list_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\sourcegraph_sourcegraph_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\spack_spack_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\spyder-ide_spyder_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\storybookjs_storybook_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\strapi_strapi_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\sveltejs_kit_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\symfony_symfony_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\systemd_systemd_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\tachiyomiorg_tachiyomi-extensions_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\tachiyomiorg_tachiyomi_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\tailscale_tailscale_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\taosdata_TDengine_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\taozhiyu_TyProAction_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\TeamNewPipe_NewPipe_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\tensorflow_tensorflow_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\termux_termux-packages_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\tgstation_tgstation_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\TP-Lab_tokens_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\trinodb_trino_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\trustwallet_assets_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\type-challenges_type-challenges_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\uBlockOrigin_uAssets_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\Ultimaker_Cura_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ultralytics_yolov5_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\unifyai_ivy_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Dota2-Gameplay_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ValveSoftware_Proton_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vectordotdev_vector_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vercel_next.js_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\vitejs_vite_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\void-linux_void-packages_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\webcompat_web-bugs_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\wjz304_Redpill_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\woocommerce_woocommerce_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\WordPress_gutenberg_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xamarin_xamarin-macios_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\xbmc_xbmc_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yt-dlp_yt-dlp_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\yuzu-emu_yuzu_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zephyrproject-rtos_zephyr_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zero-to-mastery_start-here-guidelines_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\ziglang_zig_contributor.csv
# 已处理并保存到 ./填补数据 补0+KNN近邻+问题变更等\zulip_zulip_contributor.csv
